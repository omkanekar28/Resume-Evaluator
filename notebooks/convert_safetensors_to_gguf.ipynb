# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# !git clone https://github.com/ggerganov/llama.cpp.git
# Out:
# Cloning into 'llama.cpp'...
# remote: Enumerating objects: 96283, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 96283 (delta 53), reused 35 (delta 35), pack-reused 96213 (from 3)
# Receiving objects: 100% (96283/96283), 394.46 MiB | 27.91 MiB/s, done.
# Resolving deltas: 100% (68625/68625), done.

# %%
# !pip install -q -r /content/llama.cpp/requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 52.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 44.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 54.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 101.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 27.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.6/343.6 kB 30.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 59.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 kB 5.1 MB/s eta 0:00:00
# ...

# %%
# !python /content/llama.cpp/convert_hf_to_gguf.py /content/drive/MyDrive/Procern-Training/models/Category-Prediction/2026-05-28-04:02:18.259415/merged_16bit \
    --outfile /content/drive/MyDrive/Procern-Training/models/Category-Prediction/2026-05-28-04:02:18.259415/GGUF/procern-category-prediction-q8_0.gguf \
    --outtype q8_0
# Out:
# INFO:hf-to-gguf:Loading model: merged_16bit
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:hf-to-gguf:Model architecture: Qwen2ForCausalLM
# INFO:hf-to-gguf:gguf: indexing model part 'model.safetensors'
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:token_embd.weight,         torch.bfloat16 --> Q8_0, shape = {896, 151936}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,    torch.bfloat16 --> F32, shape = {896}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,     torch.bfloat16 --> Q8_0, shape = {4864, 896}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight,     torch.bfloat16 --> Q8_0, shape = {896, 4864}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,       torch.bfloat16 --> Q8_0, shape = {896, 4864}
# INFO:hf-to-gguf:blk.0.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {896}
# INFO:hf-to-gguf:blk.0.attn_k.bias,         torch.bfloat16 --> F32, shape = {128}
# ...
